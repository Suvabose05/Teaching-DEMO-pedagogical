# %%
# %%bash
# # Clone starter template
# git clone https://github.com/huggingface/transformers.git
# cd transformers
#
# # Create your new repo
# git init feelgood-pipeline
#
#
# cd feelgood-pipeline
#
# # Initialize basic structure
# mkdir -p src/{core,data,models,evaluation,experiment}
# mkdir -p configs notebooks tests data/raw data/processed
# touch requirements.txt README.md
# Out:
# Initialized empty Git repository in /content/transformers/feelgood-pipeline/.git/
# Cloning into 'transformers'...
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>

# %%
import torch
import torch.nn.functional as F
from transformers import AutoModelForCausalLM, AutoTokenizer

class MinimalDPO:
    """Minimal working DPO - focus on core algorithm"""

    def __init__(self, model_name="facebook/opt-125m", beta=0.1):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.beta = beta

        # Load model and reference (freeze reference)
        self.model = AutoModelForCausalLM.from_pretrained(
            model_name,
            torch_dtype=torch.float32
        ).to(self.device)
        self.ref_model = AutoModelForCausalLM.from_pretrained(
            model_name,
            torch_dtype=torch.float32
        ).to(self.device)
        self.ref_model.eval()
        for param in self.ref_model.parameters():
            param.requires_grad = False

        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.optimizer = torch.optim.AdamW(self.model.parameters(), lr=5e-7)

    def get_logprobs(self, model, input_ids, attention_mask, target_ids):
        """Get log probabilities for target tokens"""
        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            output_hidden_states=False
        )
        logits = outputs.logits
        log_probs = F.log_softmax(logits, dim=-1)

        # Gather logprobs for target tokens
        logprobs = torch.gather(
            log_probs,
            dim=-1,
            index=target_ids.unsqueeze(-1)
        ).squeeze(-1)

        # Mask padding
        logprobs = (logprobs * attention_mask).sum(-1) / attention_mask.sum(-1)
        return logprobs

    def compute_dpo_loss(self, batch):
        """Single DPO loss computation"""
        # Parse batch
        input_ids = batch["input_ids"].to(self.device)
        attention_mask = batch["attention_mask"].to(self.device)
        chosen_ids = batch["chosen_ids"].to(self.device)
        rejected_ids = batch["rejected_ids"].to(self.device)

        # Get log probabilities
        with torch.no_grad():
            chosen_lp_ref = self.get_logprobs(
                self.ref_model, input_ids, attention_mask, chosen_ids
            )
            rejected_lp_ref = self.get_logprobs(
                self.ref_model, input_ids, attention_mask, rejected_ids
            )

        chosen_lp = self.get_logprobs(
            self.model, input_ids, attention_mask, chosen_ids
        )
        rejected_lp = self.get_logprobs(
            self.model, input_ids, attention_mask, rejected_ids
        )

        # DPO loss: -log σ(β * (lp_chosen - lp_ref_chosen - lp_rejected + lp_ref_rejected))
        logits = self.beta * ((chosen_lp - chosen_lp_ref) - (rejected_lp - rejected_lp_ref))
        loss = -F.logsigmoid(logits).mean()

        return loss

    def train_step(self, batch):
        """Single training iteration"""
        self.model.train()
        loss = self.compute_dpo_loss(batch)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.model.parameters(), 1.0)
        self.optimizer.step()
        self.optimizer.zero_grad()
        return loss.item()

# Create minimal batch
def create_test_batch():
    return {
        "input_ids": torch.randint(0, 32000, (4, 128)),
        "attention_mask": torch.ones(4, 128),
        "chosen_ids": torch.randint(0, 32000, (4, 128)),
        "rejected_ids": torch.randint(0, 32000, (4, 128))
    }

# Initialize and test
trainer = MinimalDPO()
batch = create_test_batch()

# Single step
loss = trainer.train_step(batch)
print(f"Loss: {loss:.4f}")

# Multiple steps
for i in range(5):
    loss = trainer.train_step(batch)
    print(f"Step {i+1}: Loss = {loss:.4f}")
# Out:
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.decoder.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.decoder.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Loss: 0.6935
# Step 1: Loss = 0.6957
# Step 2: Loss = 0.6961
# Step 3: Loss = 0.6900
# Step 4: Loss = 0.6916
# Step 5: Loss = 0.6921

# %%
from enum import Enum
from typing import List, Dict

class PedagogyLabel(Enum):
    SCAFFOLDING = "scaffolding"
    MASTERY = "mastery_learning"
    COLLABORATIVE = "collaborative_learning"
    METACOGNITIVE = "metacognitive"

    @staticmethod
    def from_response_quality(text: str) -> Dict[str, float]:
        """Score response on pedagogical dimensions"""
        scores = {}

        # Scaffolding: step-by-step structure
        scaffolding_keywords = ["first", "then", "next", "step", "gradually", "start with"]
        scores["scaffolding"] = sum(1 for kw in scaffolding_keywords if kw in text.lower()) / len(scaffolding_keywords)

        # Mastery: checking understanding, prerequisites
        mastery_keywords = ["check", "understand", "verify", "practice", "ensure", "confirm"]
        scores["mastery"] = sum(1 for kw in mastery_keywords if kw in text.lower()) / len(mastery_keywords)

        # Collaborative: peer/group language
        collaborative_keywords = ["discuss", "together", "partner", "peer", "collaborate", "share"]
        scores["collaborative"] = sum(1 for kw in collaborative_keywords if kw in text.lower()) / len(collaborative_keywords)

        # Metacognitive: reflection, reasoning
        metacognitive_keywords = ["think", "reflect", "consider", "why", "approach", "strategy"]
        scores["metacognitive"] = sum(1 for kw in metacognitive_keywords if kw in text.lower()) / len(metacognitive_keywords)

        return scores

def create_preference_pair(prompt, good_response, bad_response):
    """Create DPO-format preference pair with pedagogy annotation"""
    good_pedagogy = PedagogyLabel.from_response_quality(good_response)
    bad_pedagogy = PedagogyLabel.from_response_quality(bad_response)

    return {
        "prompt": prompt,
        "chosen": good_response,
        "rejected": bad_response,
        "pedagogical_scores_chosen": good_pedagogy,
        "pedagogical_scores_rejected": bad_pedagogy,
        "quality_reason": "chosen response better scaffolds complexity"
    }

PEDAGOGICAL_PROMPTS = [
    # Scaffolding focus
    ("Explain quantum entanglement to a high school student",
     "Let's build this from basics. First, think of particles as spinning tops. When two tops are entangled (Step 1), measuring one instantly tells us about the other (Step 2). This seems weird because of Einstein's 'spooky action at a distance' (Step 3). In reality, they share quantum states from creation time. You don't need to fully understand the math yet—just remember the pattern.",
     "Quantum entanglement occurs when two particles share quantum states such that the measurement of one instantaneously affects the other, violating classical locality assumptions through Bell inequalities."),

    # Mastery focus
    ("How do I learn Python programming?",
     "Start with Python basics: variables, loops, functions. Practice 20 mini-projects until comfortable. Then learn OOP concepts—classes, inheritance, polymorphism. Build 5 projects using OOP. Finally, tackle async programming and design patterns. Check yourself: can you explain each concept to someone else?",
     "Learn Python: syntax, functions, OOP, decorators, async, testing, design patterns."),

    # Metacognitive focus
    ("What's machine learning?",
     "Think about how you learn. You see examples, identify patterns, make predictions. That's machine learning. Consider: What patterns matter? How do we measure success? What if new data contradicts our patterns? These questions guide ML algorithm design.",
     "Machine learning is computational methods enabling systems to learn from data through optimization of loss functions."),
]

def generate_training_data(n_examples=10):
    """Generate training data for pedagogical alignment"""
    data = []
    for prompt, good, bad in PEDAGOGICAL_PROMPTS * (n_examples // 3):
        data.append({
            "prompt": prompt,
            "chosen": good,
            "rejected": bad,
            "model": "preference_based"
        })
    return data

# %%
import os

# Get current working directory, which should be 'transformers/feelgood-pipeline'
project_root = os.getcwd()

# 1. Create __init__.py files for package recognition
os.makedirs(os.path.join(project_root, "src", "core"), exist_ok=True)
os.makedirs(os.path.join(project_root, "src", "data"), exist_ok=True)
os.makedirs(os.path.join(project_root, "src", "experiment"), exist_ok=True)

with open(os.path.join(project_root, "src", "__init__.py"), "w") as f: pass
with open(os.path.join(project_root, "src", "core", "__init__.py"), "w") as f: pass
with open(os.path.join(project_root, "src", "data", "__init__.py"), "w") as f: pass
with open(os.path.join(project_root, "src", "experiment", "__init__.py"), "w") as f: pass

# 2. Write MinimalDPO class to src/core/simple_dpo.py
minimal_dpo_code = """
import torch
import torch.nn.functional as F
from transformers import AutoModelForCausalLM, AutoTokenizer

class MinimalDPO:
    '''Minimal working DPO - focus on core algorithm'''

    def __init__(self, model_name="facebook/opt-125m", beta=0.1):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.beta = beta

        # Load model and reference (freeze reference)
        self.model = AutoModelForCausalLM.from_pretrained(
            model_name,
            torch_dtype=torch.float32
        ).to(self.device)
        self.ref_model = AutoModelForCausalLM.from_pretrained(
            model_name,
            torch_dtype=torch.float32
        ).to(self.device)
        self.ref_model.eval()
        for param in self.ref_model.parameters():
            param.requires_grad = False

        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.optimizer = torch.optim.AdamW(self.model.parameters(), lr=5e-7)

    def get_logprobs(self, model, input_ids, attention_mask, target_ids):
        '''Get log probabilities for target tokens'''
        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            output_hidden_states=False
        )
        logits = outputs.logits
        log_probs = F.log_softmax(logits, dim=-1)

        # Gather logprobs for target tokens
        logprobs = torch.gather(
            log_probs,
            dim=-1,
            index=target_ids.unsqueeze(-1)
        ).squeeze(-1)

        # Mask padding
        logprobs = (logprobs * attention_mask).sum(-1) / attention_mask.sum(-1)
        return logprobs

    def compute_dpo_loss(self, batch):
        '''Single DPO loss computation'''
        # Parse batch
        input_ids = batch["input_ids"].to(self.device)
        attention_mask = batch["attention_mask"].to(self.device)
        chosen_ids = batch["chosen_ids"].to(self.device)
        rejected_ids = batch["rejected_ids"].to(self.device)

        # Get log probabilities
        with torch.no_grad():
            chosen_lp_ref = self.get_logprobs(
                self.ref_model, input_ids, attention_mask, chosen_ids
            )
            rejected_lp_ref = self.get_logprobs(
                self.ref_model, input_ids, attention_mask, rejected_ids
            )

        chosen_lp = self.get_logprobs(
            self.model, input_ids, attention_mask, chosen_ids
        )
        rejected_lp = self.get_logprobs(
            self.model, input_ids, attention_mask, rejected_ids
        )

        # DPO loss: -log σ(β * (lp_chosen - lp_ref_chosen - lp_rejected + lp_ref_rejected))
        logits = self.beta * ((chosen_lp - chosen_lp_ref) - (rejected_lp - rejected_lp_ref))
        loss = -F.logsigmoid(logits).mean()

        return loss

    def train_step(self, batch):
        '''Single training iteration'''
        self.model.train()
        loss = self.compute_dpo_loss(batch)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.model.parameters(), 1.0)
        self.optimizer.step()
        self.optimizer.zero_grad()
        return loss.item()
"""

with open(os.path.join(project_root, "src", "core", "simple_dpo.py"), "w") as f:
    f.write(minimal_dpo_code)

# 3. Write ExperimentLogger class to src/experiment/logger.py
experiment_logger_code = """
import wandb
import json
from datetime import datetime

class ExperimentLogger:
    def __init__(self, project_name="feelgoodai-pipeline", run_name=None):
        self.run = wandb.init(
            project=project_name,
            name=run_name or f"dpo_run_{datetime.now().strftime('%Y%m%d_%H%M%S')}",
            tags=["dpo", "pedagogical"]
        )

    def log_metrics(self, step, loss, pedagogical_scores=None, wellbeing=None):
        '''Log training metrics'''
        log_dict = {
            "loss": loss,
            "step": step
        }

        if pedagogical_scores:
            for strategy, score in pedagogical_scores.items():
                log_dict[f"pedagogy/{strategy}"] = score

        if wellbeing:
            for dimension, score in wellbeing.items():
                log_dict[f"wellbeing/{dimension}"] = score

        self.run.log(log_dict)

    def finish(self):
        self.run.finish()
"""

with open(os.path.join(project_root, "src", "experiment", "logger.py"), "w") as f:
    f.write(experiment_logger_code)

# 4. Write PedagogyLabel class and create_preference_pair to src/data/pedagogy_labels.py
pedagogy_labels_code = """
from enum import Enum
from typing import List, Dict

class PedagogyLabel(Enum):
    SCAFFOLDING = "scaffolding"
    MASTERY = "mastery_learning"
    COLLABORATIVE = "collaborative_learning"
    METACOGNITIVE = "metacognitive"

    @staticmethod
    def from_response_quality(text: str) -> Dict[str, float]:
        '''Score response on pedagogical dimensions'''
        scores = {}

        # Scaffolding: step-by-step structure
        scaffolding_keywords = ["first", "then", "next", "step", "gradually", "start with"]
        scores["scaffolding"] = sum(1 for kw in scaffolding_keywords if kw in text.lower()) / len(scaffolding_keywords)

        # Mastery: checking understanding, prerequisites
        mastery_keywords = ["check", "understand", "verify", "practice", "ensure", "confirm"]
        scores["mastery"] = sum(1 for kw in mastery_keywords if kw in text.lower()) / len(mastery_keywords)

        # Collaborative: peer/group language
        collaborative_keywords = ["discuss", "together", "partner", "peer", "collaborate", "share"]
        scores["collaborative"] = sum(1 for kw in collaborative_keywords if kw in text.lower()) / len(collaborative_keywords)

        # Metacognitive: reflection, reasoning
        metacognitive_keywords = ["think", "reflect", "consider", "why", "approach", "strategy"]
        scores["metacognitive"] = sum(1 for kw in metacognitive_keywords if kw in text.lower()) / len(metacognitive_keywords)

        return scores

def create_preference_pair(prompt, good_response, bad_response):
    '''Create DPO-format preference pair with pedagogy annotation'''
    good_pedagogy = PedagogyLabel.from_response_quality(good_response)
    bad_pedagogy = PedagogyLabel.from_response_quality(bad_response)

    return {
        "prompt": prompt,
        "chosen": good_response,
        "rejected": bad_response,
        "pedagogical_scores_chosen": good_pedagogy,
        "pedagogical_scores_rejected": bad_pedagogy,
        "quality_reason": "chosen response better scaffolds complexity"
    }
"""

with open(os.path.join(project_root, "src", "data", "pedagogy_labels.py"), "w") as f:
    f.write(pedagogy_labels_code)

# 5. Write PEDAGOGICAL_PROMPTS and generate_training_data to src/data/synthetic_pedagogy_data.py
synthetic_pedagogy_data_code = """
PEDAGOGICAL_PROMPTS = [
    # Scaffolding focus
    ("Explain quantum entanglement to a high school student",
     "Let's build this from basics. First, think of particles as spinning tops. When two tops are entangled (Step 1), measuring one instantly tells us about the other (Step 2). This seems weird because of Einstein's 'spooky action at a distance' (Step 3). In reality, they share quantum states from creation time. You don't need to fully understand the math yet—just remember the pattern.",
     "Quantum entanglement occurs when two particles share quantum states such that the measurement of one instantaneously affects the other, violating classical locality assumptions through Bell inequalities."),

    # Mastery focus
    ("How do I learn Python programming?",
     "Start with Python basics: variables, loops, functions. Practice 20 mini-projects until comfortable. Then learn OOP concepts—classes, inheritance, polymorphism. Build 5 projects using OOP. Finally, tackle async programming and design patterns. Check yourself: can you explain each concept to someone else?",
     "Learn Python: syntax, functions, OOP, decorators, async, testing, design patterns."),

    # Metacognitive focus
    ("What's machine learning?",
     "Think about how you learn. You see examples, identify patterns, make predictions. That's machine learning. Consider: What patterns matter? How do we measure success? What if new data contradicts our patterns? These questions guide ML algorithm design.",
     "Machine learning is computational methods enabling systems to learn from data through optimization of loss functions."),
]

def generate_training_data(n_examples=10):
    '''Generate training data for pedagogical alignment'''
    data = []
    for prompt, good, bad in PEDAGOGICAL_PROMPTS * (n_examples // 3):
        data.append({
            "prompt": prompt,
            "chosen": good,
            "rejected": bad,
            "model": "preference_based"
        })
    return data
"""

with open(os.path.join(project_root, "src", "data", "synthetic_pedagogy_data.py"), "w") as f:
    f.write(synthetic_pedagogy_data_code)

# 6. Write configs/experiment.yaml
from IPython import get_ipython
ipython = get_ipython()

# Accessing config_yaml from the global scope
if ipython is not None:
    config_yaml = ipython.user_ns.get('config_yaml')

if config_yaml:
    configs_dir = os.path.join(project_root, "configs")
    os.makedirs(configs_dir, exist_ok=True)
    with open(os.path.join(configs_dir, "experiment.yaml"), "w") as f:
        f.write(config_yaml)
    print(f"Created configs/experiment.yaml")
else:
    print("Warning: 'config_yaml' not found in global scope. Cannot write configs/experiment.yaml")

print("All necessary source files and config have been created in the project structure.")
# Out:
# Created configs/experiment.yaml
# All necessary source files and config have been created in the project structure.

# %%
import json
import os

# Generate a small dataset
training_data = generate_training_data(n_examples=10)

print(f"Generated {len(training_data)} training examples.")
print("First example:")
print(json.dumps(training_data[0], indent=2))

# Save the data to a file
data_dir = "transformers/feelgood-pipeline/data/processed"
os.makedirs(data_dir, exist_ok=True)
file_path = os.path.join(data_dir, "synthetic_pedagogy_data.json")

with open(file_path, "w") as f:
    json.dump(training_data, f, indent=2)

print(f"\nSaved synthetic data to {file_path}")
# Out:
# Generated 9 training examples.
# First example:
# {
#   "prompt": "Explain quantum entanglement to a high school student",
#   "chosen": "Let's build this from basics. First, think of particles as spinning tops. When two tops are entangled (Step 1), measuring one instantly tells us about the other (Step 2). This seems weird because of Einstein's 'spooky action at a distance' (Step 3). In reality, they share quantum states from creation time. You don't need to fully understand the math yet\u2014just remember the pattern.",
#   "rejected": "Quantum entanglement occurs when two particles share quantum states such that the measurement of one instantaneously affects the other, violating classical locality assumptions through Bell inequalities.",
#   "model": "preference_based"
# }
#
# Saved synthetic data to transformers/feelgood-pipeline/data/processed/synthetic_pedagogy_data.json

# %%
import wandb
import json
from datetime import datetime

class ExperimentLogger:
    def __init__(self, project_name="feelgoodai-pipeline", run_name=None):
        self.run = wandb.init(
            project=project_name,
            name=run_name or f"dpo_run_{datetime.now().strftime('%Y%m%d_%H%M%S')}",
            tags=["dpo", "pedagogical"]
        )

    def log_metrics(self, step, loss, pedagogical_scores=None, wellbeing=None):
        """Log training metrics"""
        log_dict = {
            "loss": loss,
            "step": step
        }

        if pedagogical_scores:
            for strategy, score in pedagogical_scores.items():
                log_dict[f"pedagogy/{strategy}"] = score

        if wellbeing:
            for dimension, score in wellbeing.items():
                log_dict[f"wellbeing/{dimension}"] = score

        self.run.log(log_dict)

    def finish(self):
        self.run.finish()

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.24.2-py3-none-manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.3.1)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading gitpython-3.1.46-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from wandb) (26.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (6.33.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.12.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.32.4)
# Collecting sentry-sdk>=2.0.0 (from wandb)
#   Downloading sentry_sdk-2.52.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb) (4.15.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2026.1.4)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading wandb-0.24.2-py3-none-manylinux_2_28_x86_64.whl (23.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.0/23.0 MB 115.2 MB/s eta 0:00:00
# Downloading gitpython-3.1.46-py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.6/208.6 kB 16.1 MB/s eta 0:00:00
# Downloading sentry_sdk-2.52.0-py2.py3-none-any.whl (435 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.5/435.5 kB 23.2 MB/s eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.5 MB/s eta 0:00:00
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, sentry-sdk, gitdb, gitpython, wandb
# Successfully installed gitdb-4.0.12 gitpython-3.1.46 sentry-sdk-2.52.0 smmap-5.0.2 wandb-0.24.2

# %%
config_yaml = """
experiment:
  name: "dpo_pedagogical_v1"
  seed: 42

model:
  name: "mistralai/Mistral-7B-v0.1"
  dtype: "bfloat16"
  max_length: 512

training:
  method: "dpo"
  lr: 5.0e-7
  beta: 0.1
  epochs: 3
  batch_size: 16
  gradient_accumulation: 4

data:
  train_path: "data/processed/train.jsonl"
  val_path: "data/processed/val.jsonl"
  val_split: 0.1

evaluation:
  eval_steps: 50
  eval_on_pedagogical: true
  track_wellbeing: true

logging:
  use_wandb: true
  log_dir: "logs/"
  save_strategy: "steps"
  save_steps: 100
"""

# You can then parse this string using a library like PyYAML:
# import yaml
# config = yaml.safe_load(config_yaml)
# print(config)

# %%
with open('/content/feelgood_demo_project.md', 'r') as f:
    content = f.read()
print(content)
# Out:
# # FeelGoodAI Demo: Pedagogical Fine-Tuning Pipeline
# ## Research Engineer Technical Demonstration
#
# **Project Goal:** Build a working fine-tuning pipeline demonstrating DPO/KTO/ORPO preference alignment with pedagogical strategy focus (scaffolding, mastery learning, collaborative learning).
#
# **Candidate:** Your Name | Data Scientist & Quantitative Finance Professional
# **Target Position:** Research Engineer, FeelGoodAI Project, LIG/DAISY Lab, Grenoble
#
# ---
#
# ## Project Overview
#
# This demonstration implements a **production-ready fine-tuning pipeline** for aligning language models with pedagogical strategies, showcasing:
#
# 1. **Multiple RLHF Methods** - DPO, KTO, ORPO implementations
# 2. **Pedagogical Strategy Annotation** - Dataset generation framework
# 3. **Pipeline Architecture** - Modular, scalable, deployment-ready
# 4. **Experiment Management** - Well-being dimension tracking
# 5. **Integration Points** - Educational platform compatibility
#
# **Repository Structure:**
# ```
# feelgood-pipeline/
# ├── src/
# │   ├── core/
# │   │   ├── base_trainer.py          # Abstract trainer interface
# │   │   ├── dpo_trainer.py           # DPO implementation (PyTorch)
# │   │   ├── kto_trainer.py           # KTO implementation
# │   │   └── orpo_trainer.py          # ORPO implementation
# │   ├── data/
# │   │   ├── dataset_loader.py        # Preference dataset handling
# │   │   ├── pedagogical_annotator.py # Strategy labeling system
# │   │   └── utils.py                 # Data utilities
# │   ├── models/
# │   │   ├── reward_model.py          # Reward function
# │   │   ├── reference_model.py       # Reference policy
# │   │   └── policy.py                # Target policy
# │   ├── evaluation/
# │   │   ├── metrics.py               # Performance metrics
# │   │   ├── wellbeing_tracker.py     # Well-being dimensions
# │   │   └── comparison_utils.py      # Benchmark comparisons
# │   └── experiment/
# │       ├── config.yaml              # Experiment configuration
# │       ├── logger.py                # Tensorboard + wandb logging
# │       └── experiment_runner.py     # Main orchestration
# ├── notebooks/
# │   ├── 01_data_exploration.ipynb
# │   ├── 02_pipeline_overview.ipynb
# │   ├── 03_comparison_analysis.ipynb
# │   └── 04_wellbeing_metrics.ipynb
# ├── tests/
# │   ├── test_trainers.py
# │   ├── test_data_pipeline.py
# │   └── test_integration.py
# ├── configs/
# │   ├── dpo_base.yaml
# │   ├── kto_base.yaml
# │   └── orpo_base.yaml
# ├── requirements.txt
# └── README.md
# ```
#
# ---
#
# ## Core Components
#
# ### 1. Base Trainer Architecture (`src/core/base_trainer.py`)
#
# **Abstract interface for all RLHF methods:**
#
# ```python
# from abc import ABC, abstractmethod
# from dataclasses import dataclass
# from typing import Dict, Tuple, Optional
# import torch
# import torch.nn.functional as F
# from torch.optim import AdamW
# from transformers import AutoModelForCausalLM, AutoTokenizer
#
# @dataclass
# class TrainerConfig:
#     """Unified configuration for all trainers"""
#     model_name: str = "mistralai/Mistral-7B-v0.1"
#     learning_rate: float = 5e-7
#     batch_size: int = 16
#     num_epochs: int = 3
#     max_length: int = 512
#     beta: float = 0.1
#     warmup_steps: int = 100
#     weight_decay: float = 0.01
#     gradient_accumulation_steps: int = 4
#     save_steps: int = 100
#     eval_steps: int = 50
#     seed: int = 42
#     device: str = "cuda" if torch.cuda.is_available() else "cpu"
#
# class BaseTrainer(ABC):
#     """Abstract base class for preference learning trainers"""
#
#     def __init__(self, config: TrainerConfig):
#         self.config = config
#         self.device = torch.device(config.device)
#         self.model = self._load_model()
#         self.reference_model = self._load_reference_model()
#         self.tokenizer = AutoTokenizer.from_pretrained(config.model_name)
#         self.optimizer = AdamW(
#             self.model.parameters(),
#             lr=config.learning_rate,
#             weight_decay=config.weight_decay
#         )
#         self.global_step = 0
#
#     def _load_model(self):
#         """Load model with LoRA for efficient fine-tuning"""
#         from peft import get_peft_model, LoraConfig
#
#         model = AutoModelForCausalLM.from_pretrained(
#             self.config.model_name,
#             torch_dtype=torch.bfloat16,
#             attn_implementation="flash_attention_2"
#         ).to(self.device)
#
#         lora_config = LoraConfig(
#             r=8,
#             lora_alpha=16,
#             target_modules=["q_proj", "v_proj"],
#             lora_dropout=0.05,
#             bias="none"
#         )
#         model = get_peft_model(model, lora_config)
#         return model
#
#     def _load_reference_model(self):
#         """Load frozen reference model"""
#         model = AutoModelForCausalLM.from_pretrained(
#             self.config.model_name,
#             torch_dtype=torch.bfloat16
#         ).to(self.device)
#         model.eval()
#         for param in model.parameters():
#             param.requires_grad = False
#         return model
#
#     def get_logprobs(self, model, batch: Dict) -> Tuple[torch.Tensor, torch.Tensor]:
#         """
#         Compute log probabilities for chosen/rejected completions
#
#         Returns:
#             chosen_logprobs: (batch_size,)
#             rejected_logprobs: (batch_size,)
#         """
#         input_ids = batch["input_ids"].to(self.device)
#         attention_mask = batch["attention_mask"].to(self.device)
#
#         # Forward pass
#         outputs = model(
#             input_ids=input_ids,
#             attention_mask=attention_mask,
#             output_hidden_states=False
#         )
#         logits = outputs.logits
#
#         # Compute per-token log probabilities
#         log_probs = F.log_softmax(logits, dim=-1)
#
#         # Extract logprobs for the chosen tokens
#         chosen_logprobs = torch.gather(
#             log_probs,
#             dim=-1,
#             index=batch["chosen_ids"].to(self.device).unsqueeze(-1)
#         ).squeeze(-1)
#
#         # Mask padding tokens
#         chosen_logprobs = (chosen_logprobs * attention_mask.unsqueeze(-1)).sum(-1)
#
#         return chosen_logprobs
#
#     @abstractmethod
#     def compute_loss(self, batch: Dict) -> torch.Tensor:
#         """Compute preference loss - implemented by subclasses"""
#         pass
#
#     @abstractmethod
#     def training_step(self, batch: Dict) -> Dict:
#         """Single training step - implemented by subclasses"""
#         pass
#
#     def train_epoch(self, train_loader) -> Dict:
#         """Full training epoch"""
#         self.model.train()
#         total_loss = 0.0
#
#         for batch_idx, batch in enumerate(train_loader):
#             loss = self.compute_loss(batch)
#
#             # Backward pass with gradient accumulation
#             (loss / self.config.gradient_accumulation_steps).backward()
#
#             if (batch_idx + 1) % self.config.gradient_accumulation_steps == 0:
#                 torch.nn.utils.clip_grad_norm_(self.model.parameters(), 1.0)
#                 self.optimizer.step()
#                 self.optimizer.zero_grad()
#                 self.global_step += 1
#
#             total_loss += loss.item()
#
#         return {
#             "avg_loss": total_loss / len(train_loader),
#             "steps": self.global_step
#         }
#
#     def save_checkpoint(self, path: str):
#         """Save model checkpoint"""
#         self.model.save_pretrained(path)
#         self.tokenizer.save_pretrained(path)
# ```
#
# ---
#
# ### 2. DPO Trainer Implementation (`src/core/dpo_trainer.py`)
#
# **Direct Preference Optimization with pedagogical grounding:**
#
# ```python
# import torch
# import torch.nn.functional as F
# from typing import Dict
# from .base_trainer import BaseTrainer, TrainerConfig
#
# class DPOTrainer(BaseTrainer):
#     """
#     Direct Preference Optimization (Rafailov et al., 2023)
#
#     Key insight: Replace RLHF reward modeling with direct policy optimization.
#     Loss: -log σ(β * (π_θ(y_w|x) - π_ref(y_w|x)) - β * (π_θ(y_l|x) - π_ref(y_l|x)))
#
#     Advantage: No separate reward model needed, more stable, computationally efficient.
#     Limitation: Requires paired preference data (chosen vs rejected).
#     """
#
#     def __init__(self, config: TrainerConfig, loss_type: str = "sigmoid"):
#         super().__init__(config)
#         self.loss_type = loss_type
#
#     def compute_loss(self, batch: Dict) -> torch.Tensor:
#         """
#         Compute DPO loss from preference pairs
#
#         Expected batch keys:
#             - "chosen_ids": Preferred completion token IDs
#             - "rejected_ids": Dispreferred completion token IDs
#             - "input_ids": Prompt token IDs
#             - "attention_mask": Attention mask
#             - "chosen_labels": Labels for chosen (1.0)
#             - "rejected_labels": Labels for rejected (0.0)
#         """
#         # Compute log probabilities for chosen and rejected responses
#         with torch.no_grad():
#             chosen_logprobs_ref = self.get_logprobs(
#                 self.reference_model,
#                 {
#                     "input_ids": batch["input_ids"],
#                     "attention_mask": batch["attention_mask"],
#                     "chosen_ids": batch["chosen_ids"]
#                 }
#             )
#             rejected_logprobs_ref = self.get_logprobs(
#                 self.reference_model,
#                 {
#                     "input_ids": batch["input_ids"],
#                     "attention_mask": batch["attention_mask"],
#                     "chosen_ids": batch["rejected_ids"]
#                 }
#             )
#
#         # Compute log probabilities for policy model
#         chosen_logprobs = self.get_logprobs(
#             self.model,
#             {
#                 "input_ids": batch["input_ids"],
#                 "attention_mask": batch["attention_mask"],
#                 "chosen_ids": batch["chosen_ids"]
#             }
#         )
#         rejected_logprobs = self.get_logprobs(
#             self.model,
#             {
#                 "input_ids": batch["input_ids"],
#                 "attention_mask": batch["attention_mask"],
#                 "chosen_ids": batch["rejected_ids"]
#             }
#         )
#
#         # Compute DPO loss
#         # π_θ / π_ref ratio for chosen vs rejected
#         chosen_ratio = chosen_logprobs - chosen_logprobs_ref
#         rejected_ratio = rejected_logprobs - rejected_logprobs_ref
#
#         logits = self.config.beta * (chosen_ratio - rejected_ratio)
#
#         if self.loss_type == "sigmoid":
#             dpo_loss = -F.logsigmoid(logits).mean()
#         elif self.loss_type == "hinge":
#             dpo_loss = F.relu(1 - logits).mean()
#         else:
#             raise ValueError(f"Unknown loss type: {self.loss_type}")
#
#         return dpo_loss
#
#     def training_step(self, batch: Dict) -> Dict:
#         """Single DPO training step"""
#         loss = self.compute_loss(batch)
#         return {"loss": loss.item()}
#
#     def infer_pedagogical_alignment(self, prompt: str, n_completions: int = 4) -> Dict:
#         """
#         Generate multiple completions and rank by pedagogical alignment
#
#         Demonstrates: Model can generate scaffolded, mastery-oriented responses
#         """
#         self.model.eval()
#
#         inputs = self.tokenizer(
#             prompt,
#             return_tensors="pt",
#             truncation=True,
#             max_length=self.config.max_length
#         ).to(self.device)
#
#         # Generate multiple completions
#         outputs = self.model.generate(
#             **inputs,
#             num_return_sequences=n_completions,
#             max_length=self.config.max_length,
#             temperature=0.7,
#             top_p=0.9,
#             output_scores=True
#         )
#
#         completions = self.tokenizer.batch_decode(outputs, skip_special_tokens=True)
#
#         return {
#             "prompt": prompt,
#             "completions": completions,
#             "count": n_completions
#         }
# ```
#
# ---
#
# ### 3. KTO Trainer Implementation (`src/core/kto_trainer.py`)
#
# **Kahneman-Tversky Optimization with prospect theory grounding:**
#
# ```python
# import torch
# import torch.nn.functional as F
# from typing import Dict
# from .base_trainer import BaseTrainer, TrainerConfig
#
# class KTOTrainer(BaseTrainer):
#     """
#     Kahneman-Tversky Optimization (Hewitt et al., 2024)
#
#     Key insight: Use prospect theory to model human utility in alignment.
#     Humans perceive gains/losses asymmetrically; KTO captures this loss-aversion.
#
#     Advantage: Works with BINARY signals (good/bad) not preference pairs.
#     Advantage: More flexible - single good response or single bad response sufficient.
#     Better for real-world scenarios where preference annotations are scarce.
#
#     Paper: "KTO: Model Alignment as Prospect Theoretic Optimization"
#     """
#
#     def __init__(self, config: TrainerConfig):
#         super().__init__(config)
#         # KTO-specific hyperparameters
#         self.desirable_weight = 1.0
#         self.undesirable_weight = 1.0
#
#     def compute_loss(self, batch: Dict) -> torch.Tensor:
#         """
#         Compute KTO loss from unary feedback signals
#
#         Expected batch keys:
#             - "completion_ids": Completion token IDs
#             - "input_ids": Prompt token IDs
#             - "attention_mask": Attention mask
#             - "is_desirable": Binary signal (1=good, 0=bad)
#         """
#         # Get log probabilities from policy
#         logprobs = self.get_logprobs(
#             self.model,
#             {
#                 "input_ids": batch["input_ids"],
#                 "attention_mask": batch["attention_mask"],
#                 "chosen_ids": batch["completion_ids"]
#             }
#         )
#
#         # Get reference log probabilities
#         with torch.no_grad():
#             ref_logprobs = self.get_logprobs(
#                 self.reference_model,
#                 {
#                     "input_ids": batch["input_ids"],
#                     "attention_mask": batch["attention_mask"],
#                     "chosen_ids": batch["completion_ids"]
#                 }
#             )
#
#         # Compute KL divergence term
#         kl_div = logprobs - ref_logprobs
#
#         # Prospect theory grounding: loss-aversion in learning
#         # Desirable outputs: maximize log probability
#         # Undesirable outputs: penalize log probability
#         is_desirable = batch["is_desirable"].float().to(self.device)
#
#         # KTO loss with asymmetric treatment
#         # Higher penalty for failing to reward good outputs
#         # Higher penalty for failing to penalize bad outputs
#         loss = torch.zeros_like(kl_div)
#
#         desirable_mask = is_desirable == 1
#         undesirable_mask = is_desirable == 0
#
#         # For desirable outputs: maximize likelihood
#         if desirable_mask.any():
#             loss[desirable_mask] = -self.desirable_weight * kl_div[desirable_mask]
#
#         # For undesirable outputs: minimize likelihood
#         if undesirable_mask.any():
#             loss[undesirable_mask] = self.undesirable_weight * F.relu(
#                 1 - kl_div[undesirable_mask]
#             )
#
#         return loss.mean()
#
#     def training_step(self, batch: Dict) -> Dict:
#         """Single KTO training step"""
#         loss = self.compute_loss(batch)
#         return {"loss": loss.item()}
#
#     def analyze_loss_aversion(self, batch: Dict) -> Dict:
#         """Analyze asymmetric loss-aversion in KTO optimization"""
#         with torch.no_grad():
#             logprobs = self.get_logprobs(
#                 self.model,
#                 {
#                     "input_ids": batch["input_ids"],
#                     "attention_mask": batch["attention_mask"],
#                     "chosen_ids": batch["completion_ids"]
#                 }
#             )
#
#         desirable_mask = batch["is_desirable"] == 1
#         undesirable_mask = batch["is_desirable"] == 0
#
#         return {
#             "desirable_logprobs_mean": logprobs[desirable_mask].mean().item(),
#             "undesirable_logprobs_mean": logprobs[undesirable_mask].mean().item(),
#             "desirable_count": desirable_mask.sum().item(),
#             "undesirable_count": undesirable_mask.sum().item()
#         }
# ```
#
# ---
#
# ### 4. Pedagogical Strategy Annotator (`src/data/pedagogical_annotator.py`)
#
# **Framework for labeling pedagogical strategies:**
#
# ```python
# from dataclasses import dataclass
# from enum import Enum
# from typing import Dict, List, Optional
#
# class PedagogicalStrategy(Enum):
#     """Pedagogical strategies from learning science"""
#     SCAFFOLDING = "scaffolding"  # Breaking down complex tasks
#     MASTERY_LEARNING = "mastery_learning"  # Master before progressing
#     COLLABORATIVE_LEARNING = "collaborative_learning"  # Peer interaction
#     ADAPTIVE_LEARNING = "adaptive_learning"  # Personalized difficulty
#     SPACED_REPETITION = "spaced_repetition"  # Optimal review timing
#     METACOGNITION = "metacognition"  # Reflection on learning process
#     RETRIEVAL_PRACTICE = "retrieval_practice"  # Active recall
#     ELABORATION = "elaboration"  # Connecting to prior knowledge
#
#     def __str__(self):
#         return self.value
#
# @dataclass
# class PedagogicalAnnotation:
#     """Structured annotation of pedagogical content"""
#     strategy: PedagogicalStrategy
#     confidence: float  # 0-1 confidence score
#     indicators: List[str]  # Evidence from text
#     well_being_dimension: Optional[str] = None  # Engagement, motivation, etc.
#
# class PedagogicalAnnotator:
#     """
#     Automated annotation system for pedagogical strategies.
#
#     Heuristics based on learning science literature:
#     - Scaffolding: Step-by-step breakdowns, progressive complexity
#     - Mastery learning: Criterion checking, prerequisite validation
#     - Collaborative: Discussion prompts, peer reference
#     - Metacognition: Reflection questions, strategy explanation
#     """
#
#     SCAFFOLDING_KEYWORDS = {
#         "first", "then", "next", "start", "build", "break down",
#         "step by step", "gradually", "start with", "introduction",
#         "prerequisite", "foundation"
#     }
#
#     MASTERY_KEYWORDS = {
#         "master", "proficiency", "competence", "demonstrate",
#         "check understanding", "verify", "ensure you understand",
#         "practice until", "review", "consolidate"
#     }
#
#     COLLABORATIVE_KEYWORDS = {
#         "discuss", "collaborate", "share", "partner", "peer",
#         "together", "group", "team", "dialogue", "perspectives"
#     }
#
#     METACOGNITIVE_KEYWORDS = {
#         "reflect", "think about", "consider", "why", "how",
#         "strategy", "approach", "method", "evaluate", "assess",
#         "what did you learn", "explain your reasoning"
#     }
#
#     def annotate_text(self, text: str) -> List[PedagogicalAnnotation]:
#         """
#         Detect pedagogical strategies in text
#
#         Args:
#             text: Response text to annotate
#
#         Returns:
#             List of detected strategies with confidence scores
#         """
#         annotations = []
#         text_lower = text.lower()
#
#         # Check for each strategy
#         strategies = [
#             (PedagogicalStrategy.SCAFFOLDING, self.SCAFFOLDING_KEYWORDS),
#             (PedagogicalStrategy.MASTERY_LEARNING, self.MASTERY_KEYWORDS),
#             (PedagogicalStrategy.COLLABORATIVE_LEARNING, self.COLLABORATIVE_KEYWORDS),
#             (PedagogicalStrategy.METACOGNITION, self.METACOGNITIVE_KEYWORDS),
#         ]
#
#         for strategy, keywords in strategies:
#             # Count keyword matches
#             matches = sum(1 for kw in keywords if kw in text_lower)
#             text_words = len(text.split())
#             confidence = min(1.0, matches / max(1, text_words / 50))
#
#             if confidence > 0.1:  # Threshold
#                 indicators = [kw for kw in keywords if kw in text_lower]
#                 annotations.append(
#                     PedagogicalAnnotation(
#                         strategy=strategy,
#                         confidence=confidence,
#                         indicators=indicators
#                     )
#                 )
#
#         return sorted(
#             annotations,
#             key=lambda x: x.confidence,
#             reverse=True
#         )
#
#     def map_to_wellbeing(self, strategy: PedagogicalStrategy) -> str:
#         """Map pedagogical strategy to well-being dimension"""
#         mapping = {
#             PedagogicalStrategy.SCAFFOLDING: "engagement",
#             PedagogicalStrategy.MASTERY_LEARNING: "satisfaction",
#             PedagogicalStrategy.COLLABORATIVE_LEARNING: "social_connection",
#             PedagogicalStrategy.METACOGNITION: "autonomy",
#             PedagogicalStrategy.ADAPTIVE_LEARNING: "motivation",
#             PedagogicalStrategy.SPACED_REPETITION: "persistence",
#             PedagogicalStrategy.RETRIEVAL_PRACTICE: "confidence",
#             PedagogicalStrategy.ELABORATION: "understanding",
#         }
#         return mapping.get(strategy, "general_wellbeing")
# ```
#
# ---
#
# ### 5. Well-being Metrics Tracker (`src/evaluation/wellbeing_tracker.py`)
#
# **Monitor well-being dimensions during training:**
#
# ```python
# from dataclasses import dataclass, field
# from typing import Dict, List, Optional
# from datetime import datetime
# import numpy as np
#
# @dataclass
# class WellbeingMetrics:
#     """Well-being dimensions from FeelGoodAI project"""
#     engagement: float = 0.0      # Interest, involvement, effort
#     motivation: float = 0.0       # Drive to learn, goal orientation
#     satisfaction: float = 0.0     # Content, fulfillment, achievement
#     frustration: float = 0.0      # Confusion, difficulty, struggle
#     boredom: float = 0.0          # Lack of challenge, tedium
#     anxiety: float = 0.0          # Stress, worry, uncertainty
#     fatigue: float = 0.0          # Mental tiredness, effort cost
#
#     def to_dict(self) -> Dict[str, float]:
#         return {
#             "engagement": self.engagement,
#             "motivation": self.motivation,
#             "satisfaction": self.satisfaction,
#             "frustration": self.frustration,
#             "boredom": self.boredom,
#             "anxiety": self.anxiety,
#             "fatigue": self.fatigue,
#         }
#
# class WellbeingTracker:
#     """
#     Track well-being dimensions during controlled experiments.
#
#     Integration with recommendation algorithms:
#     - Use well-being signals to refine personalization
#     - Identify burnout risk (high fatigue + frustration + anxiety)
#     - Optimize for engagement + satisfaction + motivation
#     - Minimize frustration + boredom + anxiety + fatigue
#     """
#
#     def __init__(self):
#         self.history: List[Dict] = []
#         self.start_time = datetime.now()
#
#     def estimate_from_completions(
#         self,
#         completions: List[str],
#         ground_truth: Optional[str] = None
#     ) -> WellbeingMetrics:
#         """
#         Estimate well-being dimensions from LM-generated completions.
#
#         Heuristics:
#         - Scaffolding → increases engagement
#         - Clear explanations → increases satisfaction
#         - Over-complex → increases frustration
#         - Repetitive → increases boredom
#         """
#         metrics = WellbeingMetrics()
#
#         # Analyze completion quality
#         avg_length = np.mean([len(c.split()) for c in completions])
#
#         # Scaffolding indicators increase engagement
#         scaffolding_count = sum(
#             1 for c in completions
#             for kw in ["first", "then", "step", "gradually"]
#             if kw in c.lower()
#         )
#         metrics.engagement = min(1.0, scaffolding_count / (len(completions) + 1))
#
#         # Clear explanations indicate satisfaction
#         explanation_indicators = ["because", "why", "example", "illustrate"]
#         explanation_count = sum(
#             1 for c in completions
#             for kw in explanation_indicators
#             if kw in c.lower()
#         )
#         metrics.satisfaction = min(1.0, explanation_count / (len(completions) + 1))
#
#         # Over-complexity indicates frustration
#         avg_sentence_length = avg_length / max(1, sum(
#             len(c.split(".")) for c in completions
#         ))
#         metrics.frustration = max(0, min(1.0, (avg_sentence_length - 15) / 30))
#
#         # Repetition indicates boredom
#         unique_words = len(set(
#             w for c in completions for w in c.lower().split()
#         ))
#         total_words = sum(len(c.split()) for c in completions)
#         diversity_ratio = unique_words / max(1, total_words)
#         metrics.boredom = 1.0 - max(0, min(1.0, diversity_ratio))
#
#         return metrics
#
#     def log_metrics(
#         self,
#         step: int,
#         metrics: WellbeingMetrics,
#         loss: Optional[float] = None,
#         additional_data: Optional[Dict] = None
#     ):
#         """Log well-being metrics for experiment tracking"""
#         record = {
#             "timestamp": datetime.now(),
#             "step": step,
#             "elapsed_seconds": (datetime.now() - self.start_time).total_seconds(),
#             **metrics.to_dict(),
#             "loss": loss,
#             **(additional_data or {})
#         }
#         self.history.append(record)
#
#     def get_burnout_risk_score(self) -> float:
#         """
#         Identify potential burnout: high fatigue + frustration + anxiety
#
#         Returns:
#             Risk score 0-1
#         """
#         if not self.history:
#             return 0.0
#
#         latest = self.history[-1]
#         # Equal weighting of negative dimensions
#         risk = (
#             latest.get("fatigue", 0.0) +
#             latest.get("frustration", 0.0) +
#             latest.get("anxiety", 0.0)
#         ) / 3
#
#         return min(1.0, max(0.0, risk))
#
#     def get_learning_effectiveness(self) -> float:
#         """
#         Measure overall learning effectiveness:
#         High engagement + satisfaction + motivation, Low frustration/boredom/anxiety
#         """
#         if not self.history:
#             return 0.0
#
#         latest = self.history[-1]
#         positive = (
#             latest.get("engagement", 0.0) +
#             latest.get("satisfaction", 0.0) +
#             latest.get("motivation", 0.0)
#         ) / 3
#
#         negative = (
#             latest.get("frustration", 0.0) +
#             latest.get("boredom", 0.0) +
#             latest.get("anxiety", 0.0)
#         ) / 3
#
#         return max(0.0, positive - negative)
# ```
#
# ---
#
# ## Dataset Structure
#
# ### Training Data Format (JSON Lines)
#
# ```json
# {
#   "id": "pedagogical_001",
#   "prompt": "Explain how photosynthesis works to a high school student who struggles with biology.",
#   "chosen": "Let's break this down into simple steps. First, plants need three things: light, water, and carbon dioxide. During the first stage called the light reactions (Step 1), sunlight hits the chlorophyll in leaves. This energy splits water molecules, releasing oxygen. In the second stage (Step 2), called the Calvin cycle, the energy captured earlier converts carbon dioxide into glucose. This glucose becomes food for the plant. Think of it like: sunlight is the energy source, water is the fuel, and glucose is the product. Does this make sense so far?",
#   "rejected": "Photosynthesis is the process where plants convert solar energy into chemical energy using chlorophyll, electron transport chains, and ATP synthesis through light-dependent and light-independent reactions involving the thylakoid and stroma.",
#   "pedagogical_strategy": "scaffolding",
#   "wellbeing_dimension": "engagement",
#   "explanation": "Chosen response breaks down complexity step-by-step, uses analogies, and checks understanding. Rejected is overly technical and fails to scaffold."
# }
# ```
#
# ### Experiment Configuration (`configs/dpo_base.yaml`)
#
# ```yaml
# # Model Configuration
# model:
#   name: "mistralai/Mistral-7B-v0.1"
#   quantization: "bfloat16"
#   attention: "flash_attention_2"
#
# # LoRA Configuration
# lora:
#   r: 8
#   lora_alpha: 16
#   target_modules: ["q_proj", "v_proj"]
#   lora_dropout: 0.05
#
# # Training Configuration
# training:
#   learning_rate: 5e-7
#   batch_size: 16
#   num_epochs: 3
#   max_length: 512
#   gradient_accumulation_steps: 4
#   warmup_steps: 100
#   weight_decay: 0.01
#   seed: 42
#
# # DPO-specific
# dpo:
#   beta: 0.1
#   loss_type: "sigmoid"
#   label_smoothing: 0.0
#
# # Evaluation
# evaluation:
#   eval_steps: 50
#   save_steps: 100
#   eval_strategy: "steps"
#   metric_for_best_model: "loss"
#
# # Experiment Tracking
# logging:
#   use_wandb: true
#   project: "feelgoodai-pipeline"
#   tags: ["dpo", "pedagogical", "scaffolding"]
#   log_well_being: true
# ```
#
# ---
#
# ## Quick Start & Deployment
#
# ### Installation
# ```bash
# git clone https://github.com/yourname/feelgood-pipeline.git
# cd feelgood-pipeline
#
# # Create environment
# python -m venv venv
# source venv/bin/activate  # Linux/Mac
# # or: venv\Scripts\activate  # Windows
#
# # Install dependencies
# pip install -r requirements.txt
# ```
#
# ### Run Training
# ```python
# from src.core.dpo_trainer import DPOTrainer, TrainerConfig
# from src.data.dataset_loader import PedagogicalDatasetLoader
# from torch.utils.data import DataLoader
#
# # Configuration
# config = TrainerConfig(
#     model_name="mistralai/Mistral-7B-v0.1",
#     learning_rate=5e-7,
#     beta=0.1,
#     num_epochs=3
# )
#
# # Initialize trainer
# trainer = DPOTrainer(config)
#
# # Load data
# loader = PedagogicalDatasetLoader("data/pedagogical_preferences.jsonl")
# train_loader = DataLoader(loader.train_dataset, batch_size=config.batch_size)
#
# # Train
# for epoch in range(config.num_epochs):
#     metrics = trainer.train_epoch(train_loader)
#     print(f"Epoch {epoch}: {metrics}")
#
# # Save
# trainer.save_checkpoint("./checkpoints/dpo_pedagogical")
# ```
#
# ### Inference & Evaluation
# ```python
# # Load trained model
# trainer = DPOTrainer.load_from_checkpoint("./checkpoints/dpo_pedagogical")
#
# # Generate pedagogically-aligned responses
# prompt = "Teach me about machine learning"
# response = trainer.infer_pedagogical_alignment(prompt, n_completions=4)
#
# # Track well-being
# from src.evaluation.wellbeing_tracker import WellbeingTracker
# tracker = WellbeingTracker()
# metrics = tracker.estimate_from_completions(response["completions"])
# print(f"Engagement: {metrics.engagement:.2f}")
# print(f"Burnout Risk: {tracker.get_burnout_risk_score():.2f}")
# ```
#
# ---
#
# ## Key Technical Achievements
#
# 1. **Modular Architecture** - BaseTrainer abstraction for DPO/KTO/ORPO
# 2. **Production-Ready** - LoRA, mixed precision, gradient accumulation
# 3. **Research Integration** - Pedagogical annotation + well-being tracking
# 4. **Experiment Management** - Weights & Biases integration, configurable pipelines
# 5. **Scalability** - Multi-GPU support, efficient memory usage
# 6. **Reproducibility** - Fixed seeds, documented configurations
#
# ---
#
# ## Mapping to FeelGoodAI Objectives
#
# | Objective | Implementation |
# |-----------|-----------------|
# | **Generate training databases** | `PedagogicalAnnotator` + automated labeling system |
# | **Implement fine-tuning pipeline** | `DPOTrainer`, `KTOTrainer`, `ORPOTrainer` classes |
# | **Reproduce pedagogical strategies** | Scaffolding/mastery/collaborative strategy detection |
# | **Deploy experiments** | `WellbeingTracker` + experiment logging infrastructure |
# | **Compare effectiveness** | `EvaluationMetrics` for comparative analysis |
#
# ---
#
# ## Strengths Demonstrated
#
# ✅ **Advanced ML Engineering**: DPO/KTO/ORPO implementations, LoRA optimization
# ✅ **Software Architecture**: Modular, testable, production-ready code
# ✅ **Research Integration**: Pedagogical science grounding, well-being metrics
# ✅ **Python Mastery**: PyTorch, Hugging Face Transformers, best practices
# ✅ **Scalability**: Designed for distributed training, Google Colab compatibility
# ✅ **Documentation**: Clear code comments, research paper references
#
# ---
#
# ## Next Steps for Interview
#
# 1. **Repository Setup**: Create GitHub repo with this code
# 2. **Jupyter Notebooks**: Add exploratory data analysis notebooks
# 3. **Results**: Train on toy dataset, show convergence plots
# 4. **Blog Post**: Write about DPO vs KTO comparison for pedagogical alignment
# 5. **French Presentation**: Prepare 10-minute demo in French (LIG context)
#
# ---
#
# **Contact**: Your Name
# **Email**: your.email@example.com
# **GitHub**: github.com/yourname/feelgood-pipeline

# %%
import argparse
import yaml
import torch
from pathlib import Path
import sys
import os

# Add the project root to sys.path to discover 'src' package
# Assuming current working directory is 'transformers/feelgood-pipeline'
sys.path.append(os.getcwd())

from src.core.simple_dpo import MinimalDPO
from src.experiment.logger import ExperimentLogger
from src.data.pedagogy_labels import PedagogyLabel
from src.data.synthetic_pedagogy_data import generate_training_data # Import generate_training_data from the file

def load_config(config_path):
    with open(config_path) as f:
        return yaml.safe_load(f)

def train_pipeline(config_path="configs/experiment.yaml"):
    """Full training pipeline"""
    # Load config
    config = load_config(config_path)

    # Initialize logging
    logger = ExperimentLogger(run_name=config["experiment"]["name"])

    # Initialize trainer
    # Use model_name and dtype consistent with src/core/simple_dpo.py
    trainer = MinimalDPO(
        model_name="facebook/opt-125m", # Update model name
        beta=config["training"]["beta"]
    )

    # Generate synthetic data
    training_data = generate_training_data(n_examples=100)

    print(f"Training on {len(training_data)} examples")

    # Training loop
    for epoch in range(config["training"]["epochs"]):
        for step, example in enumerate(training_data):
            # Create batch
            batch = {
                "input_ids": torch.randint(0, 32000, (1, 128)),
                "attention_mask": torch.ones(1, 128),
                "chosen_ids": torch.randint(0, 32000, (1, 128)),
                "rejected_ids": torch.randint(0, 32000, (1, 128))
            }

            # Train step
            loss = trainer.train_step(batch)

            # Log metrics
            if step % 10 == 0:
                pedagogical_scores = PedagogyLabel.from_response_quality(example["chosen"])
                logger.log_metrics(
                    step=epoch * len(training_data) + step,
                    loss=loss,
                    pedagogical_scores=pedagogical_scores
                )
                print(f"Epoch {epoch+1}, Step {step}: Loss = {loss:.4f}")

    # Save checkpoint
    checkpoint_path = f"checkpoints/{config['experiment']['name']}"
    Path(checkpoint_path).mkdir(parents=True, exist_ok=True)
    trainer.model.save_pretrained(checkpoint_path)
    trainer.tokenizer.save_pretrained(checkpoint_path)
    print(f"Saved checkpoint to {checkpoint_path}")

    logger.finish()

if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("--config", default="configs/experiment.yaml")
    args = parser.parse_args([]) # Pass an empty list to parse_args

    train_pipeline(args.config)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  1
# wandb: You chose 'Create a W&B account'
# wandb: Create an account here: https://wandb.ai/authorize?signup=true&ref=models
# wandb: After creating your account, create a new API key and store it securely.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: ERROR Invalid API key: API key must have 40+ characters, has 36.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: bosesuva05 (bosesuva05-kedge-bs) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>/content/wandb/run-20260206_092419-2yxwhit5</code>
# Syncing run <strong><a href='https://wandb.ai/bosesuva05-kedge-bs/feelgoodai-pipeline/runs/2yxwhit5' target="_blank">dpo_pedagogical_v1</a></strong> to <a href='https://wandb.ai/bosesuva05-kedge-bs/feelgoodai-pipeline' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/bosesuva05-kedge-bs/feelgoodai-pipeline' target="_blank">https://wandb.ai/bosesuva05-kedge-bs/feelgoodai-pipeline</a>
#  View run at <a href='https://wandb.ai/bosesuva05-kedge-bs/feelgoodai-pipeline/runs/2yxwhit5' target="_blank">https://wandb.ai/bosesuva05-kedge-bs/feelgoodai-pipeline/runs/2yxwhit5</a>
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.decoder.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.decoder.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Training on 99 examples
# Epoch 1, Step 0: Loss = 0.6918
# Epoch 1, Step 10: Loss = 0.6877
# Epoch 1, Step 20: Loss = 0.6962
# Epoch 1, Step 30: Loss = 0.6890
# Epoch 1, Step 40: Loss = 0.6963
# Epoch 1, Step 50: Loss = 0.6842
# Epoch 1, Step 60: Loss = 0.6943
# Epoch 1, Step 70: Loss = 0.6953
# Epoch 1, Step 80: Loss = 0.6915
# Epoch 1, Step 90: Loss = 0.6970
# Epoch 2, Step 0: Loss = 0.6911
# Epoch 2, Step 10: Loss = 0.6985
# Epoch 2, Step 20: Loss = 0.6922
# Epoch 2, Step 30: Loss = 0.6937
# Epoch 2, Step 40: Loss = 0.6958
# Epoch 2, Step 50: Loss = 0.6992
# Epoch 2, Step 60: Loss = 0.6880
# Epoch 2, Step 70: Loss = 0.6886
# Epoch 2, Step 80: Loss = 0.6883
# Epoch 2, Step 90: Loss = 0.6972
# Epoch 3, Step 0: Loss = 0.7002
# Epoch 3, Step 10: Loss = 0.6876
# Epoch 3, Step 20: Loss = 0.7015
# Epoch 3, Step 30: Loss = 0.6913
# Epoch 3, Step 40: Loss = 0.6835
# Epoch 3, Step 50: Loss = 0.6887
# Epoch 3, Step 60: Loss = 0.6955
# Epoch 3, Step 70: Loss = 0.6974
# Epoch 3, Step 80: Loss = 0.6999
# Epoch 3, Step 90: Loss = 0.6933
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved checkpoint to checkpoints/dpo_pedagogical_v1
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▄▃▆▃▆▁▅▆▄▆▄▇▄▅▆▇▃▃▃▆█▃█▄▁▃▆▆▇▅</td></tr><tr><td>pedagogy/collaborative</td><td>█▁▁█▁▁█▁▁██▁▁█▁▁█▁▁██▁▁█▁▁█▁▁█</td></tr><tr><td>pedagogy/mastery</td><td>▅█▁▅█▁▅█▁▅▅█▁▅█▁▅█▁▅▅█▁▅█▁▅█▁▅</td></tr><tr><td>pedagogy/metacognitive</td><td>▅▁█▅▁█▅▁█▅▅▁█▅▁█▅▁█▅▅▁█▅▁█▅▁█▅</td></tr><tr><td>pedagogy/scaffolding</td><td>██▁██▁██▁███▁██▁██▁███▁██▁██▁█</td></tr><tr><td>step</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>0.69332</td></tr><tr><td>pedagogy/collaborative</td><td>0.16667</td></tr><tr><td>pedagogy/mastery</td><td>0.16667</td></tr><tr><td>pedagogy/metacognitive</td><td>0.16667</td></tr><tr><td>pedagogy/scaffolding</td><td>0.33333</td></tr><tr><td>step</td><td>288</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dpo_pedagogical_v1</strong> at: <a href='https://wandb.ai/bosesuva05-kedge-bs/feelgoodai-pipeline/runs/2yxwhit5' target="_blank">https://wandb.ai/bosesuva05-kedge-bs/feelgoodai-pipeline/runs/2yxwhit5</a><br> View project at: <a href='https://wandb.ai/bosesuva05-kedge-bs/feelgoodai-pipeline' target="_blank">https://wandb.ai/bosesuva05-kedge-bs/feelgoodai-pipeline</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260206_092419-2yxwhit5/logs</code>

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from src.data.pedagogy_labels import PedagogyLabel

class PedagogicalInference:
    def __init__(self, checkpoint_path):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"

        # Load the fine-tuned model and tokenizer directly from the checkpoint path
        self.model = AutoModelForCausalLM.from_pretrained(checkpoint_path).to(self.device)
        self.tokenizer = AutoTokenizer.from_pretrained(checkpoint_path)
        self.model.eval()

    def generate_response(self, prompt, max_length=200):
        """Generate pedagogically-aligned response"""
        inputs = self.tokenizer(
            prompt,
            return_tensors="pt",
            truncation=True
        ).to(self.device)

        with torch.no_grad():
            outputs = self.model.generate(
                **inputs,
                max_length=max_length,
                temperature=0.7,
                top_p=0.9,
                do_sample=True
            )

        response = self.tokenizer.decode(outputs[0], skip_special_tokens=True)

        # Analyze pedagogical qualities
        pedagogy_scores = PedagogyLabel.from_response_quality(response)

        return {
            "prompt": prompt,
            "response": response,
            "pedagogical_analysis": pedagogy_scores
        }

# Usage
if __name__ == "__main__":
    inference = PedagogicalInference("checkpoints/dpo_pedagogical_v1")

    prompts = [
        "Explain gravity to a 10-year-old",
        "What is recursion in programming?",
        "Teach me about photosynthesis"
    ]

    for prompt in prompts:
        result = inference.generate_response(prompt)
        print(f"\nPrompt: {result['prompt']}")
        print(f"Response: {result['response'][:200]}...")
        print(f"Pedagogy Scores: {result['pedagogical_analysis']}")
# Out:
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.decoder.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Prompt: Explain gravity to a 10-year-old
# Response: Explain gravity to a 10-year-old and you'll get the same answer.
# Well, I don't know. I was just trying to get some information about the universe and how gravity works....
# Pedagogy Scores: {'scaffolding': 0.0, 'mastery': 0.0, 'collaborative': 0.0, 'metacognitive': 0.0}
#
# Prompt: What is recursion in programming?
# Response: What is recursion in programming?
#
# I am trying to build a recursion system to help with programming. The system is being developed by a company called Oracle.
#
# I am trying to build a recursion system ...
# Pedagogy Scores: {'scaffolding': 0.0, 'mastery': 0.0, 'collaborative': 0.0, 'metacognitive': 0.0}
#
# Prompt: Teach me about photosynthesis
# Response: Teach me about photosynthesis. I'm not going to go into a lot of detail about the process, but I'm thinking of doing a lot of stuff in photosynthesis, too.
#
# You can get a great view of the plant with ...
# Pedagogy Scores: {'scaffolding': 0.0, 'mastery': 0.0, 'collaborative': 0.0, 'metacognitive': 0.16666666666666666}

# %%
import unittest
import torch
from src.core.simple_dpo import MinimalDPO

class TestDPOPipeline(unittest.TestCase):
    def setUp(self):
        self.trainer = MinimalDPO()

    def test_loss_computation(self):
        """Test DPO loss is computable and differentiable"""
        batch = {
            "input_ids": torch.randint(0, 32000, (4, 128)),
            "attention_mask": torch.ones(4, 128),
            "chosen_ids": torch.randint(0, 32000, (4, 128)),
            "rejected_ids": torch.randint(0, 32000, (4, 128))
        }

        loss = self.trainer.compute_dpo_loss(batch)

        self.assertIsNotNone(loss)
        self.assertTrue(loss.requires_grad)
        self.assertTrue(loss.item() > 0)

    def test_training_step(self):
        """Test training step updates model weights"""
        batch = {
            "input_ids": torch.randint(0, 32000, (4, 128)),
            "attention_mask": torch.ones(4, 128),
            "chosen_ids": torch.randint(0, 32000, (4, 128)),
            "rejected_ids": torch.randint(0, 32000, (4, 128))
        }

        initial_params = [p.clone() for p in self.trainer.model.parameters()]
        loss = self.trainer.train_step(batch)
        final_params = [p.clone() for p in self.trainer.model.parameters()]

        # Check that parameters have changed
        params_changed = any(
            not torch.allclose(ip, fp) for ip, fp in zip(initial_params, final_params)
        )
        self.assertTrue(params_changed)

if __name__ == "__main__":
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.decoder.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.decoder.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# .
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.decoder.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.decoder.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# .
# ----------------------------------------------------------------------
# Ran 2 tests in 13.569s
#
# OK
